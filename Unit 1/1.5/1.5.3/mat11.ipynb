# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

x=np.array([1,8])
y=np.array([9,5])
plt.plot(x,y,'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array([1,8])
y=np.array([9,5])
plt.plot(x,y,'o-.r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
b=np.random.default_rng(100)

# %%
c=b.integers(low=10,high=1000,size=2500)

# %%
plt.subplot(2,2,1)
plt.plot(c)
plt.subplot(2,1,2)
plt.plot(c)
