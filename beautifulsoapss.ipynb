# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://en.wikipedia.org/wiki/The_World%27s_Billionaires"
htmlres=requests.get(url)

# %%
print(htmlres.content)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>The World\'s Billionaires - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-cl
# ...

# %%
response1=BeautifulSoup(htmlres.content,'html.parser')

# %%
collecteddata=response1.find('wikitable')

# %%
print(collecteddata)
# Out:
# None

# %%
header=[]
for i in response1.find_all('tr'):
    print(i)
# Out:
# <tr><td class="infobox-subheader" colspan="2"><span class="nowrap">List of the world's <a href="/wiki/Billionaire" title="Billionaire">billionaires</a>, ranked in order of <a href="/wiki/Net_worth" title="Net worth">net worth</a></span></td></tr>
# ...
